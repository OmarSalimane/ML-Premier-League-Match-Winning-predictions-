# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date           time            comp        round  day venue result  \
# 0  2020-09-21  20:15 (21:15)  Premier League  Matchweek 2  Mon  Away      W
# 2  2020-09-27  16:30 (17:30)  Premier League  Matchweek 3  Sun  Home      L
# 4  2020-10-03  17:30 (18:30)  Premier League  Matchweek 4  Sat  Away      D
# 5  2020-10-17  17:30 (18:30)  Premier League  Matchweek 5  Sat  Home      W
# 7  2020-10-24  12:30 (13:30)  Premier League  Matchweek 6  Sat  Away      D
#
#    gf  ga        opponent  ...  match report  notes  sh  sot  dist fk pk  \
# 0   3   1          Wolves  ...  Match Report    NaN  13    8  21.1  2  1
# 2   2   5  Leicester City  ...  Match Report    NaN  16    5  19.8  1  0
# 4   1   1    Leeds United  ...  Match Report    NaN  23    1  18.2  1  0
# 5   1   0         Arsenal  ...  Match Report    NaN  13    5  17.7  0  0
# 7   1   1        West Ham  ...  Match Report    NaN  14    7  20.9  1  0
#
#   pkatt  season             team
# 0     1    2024  Manchester City
# ...

# %%
matches.shape
# Out:
# (4788, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City             266
# Liverpool                   266
# Chelsea                     266
# Manchester United           266
# Tottenham Hotspur           266
# Aston Villa                 228
# Brighton and Hove Albion    228
# Wolverhampton Wanderers     228
# Newcastle United            228
# Crystal Palace              228
# Everton                     228
# Arsenal                     228
# West Ham United             228
# Leicester City              228
# Southampton                 190
# Burnley                     190
# Leeds United                152
# Fulham                      152
# Sheffield United            152
# Bournemouth                 114
# Brentford                   114
# West Bromwich Albion         76
# Nottingham Forest            76
# Watford                      76
# Norwich City                 76
# Luton Town                   38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date           time            comp         round  day venue result  \
# 1   2019-08-09  20:00 (21:00)  Premier League   Matchweek 1  Fri  Home      W
# 1   2019-08-09  20:00 (21:00)  Premier League   Matchweek 1  Fri  Home      W
# 3   2019-08-17  15:00 (16:00)  Premier League   Matchweek 2  Sat  Away      W
# 3   2019-08-17  15:00 (16:00)  Premier League   Matchweek 2  Sat  Away      W
# 4   2019-08-24  17:30 (18:30)  Premier League   Matchweek 3  Sat  Home      W
# ..         ...            ...             ...           ...  ...   ...    ...
# 57  2024-04-24  20:00 (21:00)  Premier League  Matchweek 29  Wed  Away      L
# 58  2024-04-27  12:30 (14:30)  Premier League  Matchweek 35  Sat  Away      D
# 59  2024-05-05  16:30 (18:30)  Premier League  Matchweek 36  Sun  Home      W
# 60  2024-05-13  20:00 (22:00)  Premier League  Matchweek 37  Mon  Away      D
# 61  2024-05-19  16:00 (18:00)  Premier League  Matchweek 38  Sun  Home      W
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 2     126
# Matchweek 33    126
# Matchweek 23    126
# Matchweek 24    126
# Matchweek 16    126
# Matchweek 25    126
# Matchweek 26    126
# Matchweek 29    126
# Matchweek 27    126
# Matchweek 28    126
# Matchweek 3     126
# Matchweek 30    126
# Matchweek 31    126
# Matchweek 32    126
# Matchweek 34    126
# Matchweek 35    126
# Matchweek 36    126
# Matchweek 37    126
# Matchweek 22    126
# Matchweek 21    126
# Matchweek 20    126
# Matchweek 1     126
# Matchweek 4     126
# Matchweek 5     126
# Matchweek 6     126
# Matchweek 7     126
# Matchweek 8     126
# Matchweek 9     126
# Matchweek 10    126
# Matchweek 11    126
# Matchweek 12    126
# Matchweek 13    126
# Matchweek 14    126
# Matchweek 15    126
# Matchweek 17    126
# Matchweek 18    126
# Matchweek 19    126
# Matchweek 38    126
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss              int64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh                int64
# sot               int64
# dist            float64
# fk                int64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date           time         round  day venue result  gf  ga  \
# 0  2020-09-21  20:15 (21:15)   Matchweek 2  Mon  Away      W   3   1
# 2  2020-09-27  16:30 (17:30)   Matchweek 3  Sun  Home      L   2   5
# 4  2020-10-03  17:30 (18:30)   Matchweek 4  Sat  Away      D   1   1
# 5  2020-10-17  17:30 (18:30)   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30 (13:30)   Matchweek 6  Sat  Away      D   1   1
# ..        ...            ...           ...  ...   ...    ...  ..  ..
# 87 2020-07-07  18:00 (19:00)  Matchweek 34  Tue  Away      L   1   2
# 88 2020-07-11  12:30 (13:30)  Matchweek 35  Sat  Home      L   0   4
# 89 2020-07-14  20:15 (21:15)  Matchweek 36  Tue  Away      L   0   1
# 90 2020-07-18  17:30 (18:30)  Matchweek 37  Sat  Home      L   0   2
# 91 2020-07-26  16:00 (17:00)  Matchweek 38  Sun  Away      L   0   5
#
#            opponent   xg  ...  match report  sh  sot  dist fk pk pkatt  \
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date           time         round  day venue result  gf  ga  \
# 0  2020-09-21  20:15 (21:15)   Matchweek 2  Mon  Away      W   3   1
# 2  2020-09-27  16:30 (17:30)   Matchweek 3  Sun  Home      L   2   5
# 4  2020-10-03  17:30 (18:30)   Matchweek 4  Sat  Away      D   1   1
# 5  2020-10-17  17:30 (18:30)   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30 (13:30)   Matchweek 6  Sat  Away      D   1   1
# ..        ...            ...           ...  ...   ...    ...  ..  ..
# 87 2020-07-07  18:00 (19:00)  Matchweek 34  Tue  Away      L   1   2
# 88 2020-07-11  12:30 (13:30)  Matchweek 35  Sat  Home      L   0   4
# 89 2020-07-14  20:15 (21:15)  Matchweek 36  Tue  Away      L   0   1
# 90 2020-07-18  17:30 (18:30)  Matchweek 37  Sat  Home      L   0   2
# 91 2020-07-26  16:00 (17:00)  Matchweek 38  Sun  Away      L   0   5
#
#            opponent   xg  ...  fk  pk  pkatt season             team target  \
# ...

# %%
result_counts = matches['result'].value_counts()

plt.figure(figsize=(8, 6))
result_counts.plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Distribution of Match Results')
plt.ylabel('')
plt.show()

# %%
# Scatter plot between xG and Shots on Target
plt.figure(figsize=(7, 5))
sns.scatterplot(x=matches['xg'], y=matches['sot'])
plt.title("xG vs. Shots on Target")
plt.xlabel("Expected Goals (xG)")
plt.ylabel("Shots on Target (SOT)")
plt.show()

# %%
statistics = matches[['xg', 'poss', 'sot']].describe().T[['mean', 'std']]

# Calculate Mode
mode_xg = matches['xg'].mode()[0]
mode_possession = matches['poss'].mode()[0]
mode_sot = matches['sot'].mode()[0]

# Prepare the result
statistics['mode_xg'] = mode_xg
statistics['mode_poss'] = mode_possession
statistics['mode_sot'] = mode_sot

statistics
# Out:
#            mean        std  mode_xg  mode_poss  mode_sot
# xg     1.396512   0.828847      0.9         53         3
# poss  50.432957  12.810958      0.9         53         3
# sot    4.261278   2.459963      0.9         53         3

# %%
# Calculate the class distribution of the target variable (e.g., 'target' column)
class_distribution = matches['target'].value_counts(normalize=True) * 100

# Get the count and percentage of each class
class_counts = matches['target'].value_counts()

# Create a summary table for easier readability
class_summary = pd.DataFrame({
    'Class': class_counts.index,
    'Count': class_counts.values,
    'Percentage': class_distribution.values
})

print(class_summary)
# Out:
#    Class  Count  Percentage
# 0      0   2893   60.421888
# 1      1   1895   39.578112

# %%
# Expected Goals (xG) vs Actual Goals (gf) across all matches
plt.figure(figsize=(10, 6))
sns.scatterplot(data=matches, x='xg', y='gf', hue='venue', style='result')
plt.title('Expected Goals (xG) vs Actual Goals Scored (gf)')
plt.xlabel('Expected Goals (xG)')
plt.ylabel('Goals Scored (gf)')
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=60, max_depth=10, min_samples_split=5, random_state=42, bootstrap=True)

# %%
# End date for the 2022/2023 season is 2023-05-29, we aim to train our model on all previous seasons
train = matches[matches["date"] < '2023-05-29']

# %%
# We aim to test our model on the 2023/2024 season
test = matches[matches["date"] > '2023-05-29']

# %%
predictors = ["venue_code", "opp_code", "xg", "xga", "poss", "sot", "sh", "pk", "pkatt", "fk"]

# %%
# Plot histograms for major numerical features
matches[['xg', 'poss', 'sot']].hist(bins=15, figsize=(15, 5), layout=(1, 3))
plt.suptitle("Distribution of Key Features")
plt.show()

# %%
# Plot box plots for major numerical features
plt.figure(figsize=(15, 5))
sns.boxplot(data=matches[['xg', 'poss', 'sot']])
plt.title("Box Plot for Outliers in Key Features")
plt.show()

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=60,
#                        random_state=42)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.7657894736842106

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          391   71
# 1          107  191

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test["target"], preds), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted', fontsize=12, fontweight='bold')
plt.ylabel('Actual', fontsize=12, fontweight='bold')
plt.show()

# %%
from sklearn.metrics import precision_score
# This shows us the percentage of how many wins we predicted correctly
precision_score(test["target"], preds)
# Out:
# 0.7290076335877863

# %%
avg_shotsontarget_by_season = matches.groupby('season')['sot'].mean()

plt.figure(figsize=(8, 6))
avg_shotsontarget_by_season.plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Average Shots On Target per Game by Season')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(matches['poss'], bins=20, kde=True, color='green')
plt.title('Possession Percentage Distribution')
plt.xlabel('Possession Percentage')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# In this second part of the project, we'll try to improve the model's precision with rolling averages:
# This will require us to split our matches data frame by team (e.g. Manchester City), this is just to compute rolling averages for team performance, in our case, the team's overall performance in the past 2 games (Excluding the actual matchday) will be assesed and used to see if it could give a boost to our precision.

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(2, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date           time         round  day venue result  gf  ga  \
# 2  2019-08-17  17:30 (18:30)   Matchweek 2  Sat  Home      D   2   2
# 2  2019-08-17  17:30 (18:30)   Matchweek 2  Sat  Home      D   2   2
# 3  2019-08-25  14:00 (15:00)   Matchweek 3  Sun  Away      W   3   1
# 3  2019-08-25  14:00 (15:00)   Matchweek 3  Sun  Away      W   3   1
# 4  2019-08-31  15:00 (16:00)   Matchweek 4  Sat  Home      W   4   0
# ..        ...            ...           ...  ...   ...    ...  ..  ..
# 55 2024-04-28  16:30 (18:30)  Matchweek 35  Sun  Away      W   2   0
# 56 2024-05-04  17:30 (19:30)  Matchweek 36  Sat  Home      W   5   1
# 57 2024-05-11  12:30 (14:30)  Matchweek 37  Sat  Away      W   4   0
# 58 2024-05-14  20:00 (22:00)  Matchweek 34  Tue  Away      W   2   0
# 59 2024-05-19  16:00 (18:00)  Matchweek 38  Sun  Home      W   3   1
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\somar\AppData\Local\Temp\ipykernel_29868\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date           time         round  day venue  \
# team
# Arsenal                 2  2019-08-24  17:30 (18:30)   Matchweek 3  Sat  Away
#                         3  2019-09-01  16:30 (17:30)   Matchweek 4  Sun  Home
#                         4  2019-09-15  16:30 (17:30)   Matchweek 5  Sun  Away
#                         87 2019-09-22  16:30 (17:30)   Matchweek 6  Sun  Home
#                         89 2019-09-30  20:00 (21:00)   Matchweek 7  Mon  Away
# ...                               ...            ...           ...  ...   ...
# Wolverhampton Wanderers 41 2024-04-24  19:45 (20:45)  Matchweek 29  Wed  Home
#                         42 2024-04-27  15:00 (17:00)  Matchweek 35  Sat  Home
#                         43 2024-05-04  17:30 (19:30)  Matchweek 36  Sat  Away
#                         44 2024-05-11  15:00 (17:00)  Matchweek 37  Sat  Home
#                         45 2024-05-19  16:00 (18:00)  Matchweek 38  Sun  Away
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date           time         round  day venue result  gf  ga  \
# 2  2019-08-24  17:30 (18:30)   Matchweek 3  Sat  Away      L   1   3
# 3  2019-09-01  16:30 (17:30)   Matchweek 4  Sun  Home      D   2   2
# 4  2019-09-15  16:30 (17:30)   Matchweek 5  Sun  Away      D   2   2
# 87 2019-09-22  16:30 (17:30)   Matchweek 6  Sun  Home      W   3   2
# 89 2019-09-30  20:00 (21:00)   Matchweek 7  Mon  Away      D   1   1
# ..        ...            ...           ...  ...   ...    ...  ..  ..
# 41 2024-04-24  19:45 (20:45)  Matchweek 29  Wed  Home      L   0   1
# 42 2024-04-27  15:00 (17:00)  Matchweek 35  Sat  Home      W   2   1
# 43 2024-05-04  17:30 (19:30)  Matchweek 36  Sat  Away      L   1   5
# 44 2024-05-11  15:00 (17:00)  Matchweek 37  Sat  Home      L   1   3
# 45 2024-05-19  16:00 (18:00)  Matchweek 38  Sun  Away      L   0   2
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
#This function is defined to easily make predictions instead of repeating the train/test method
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-05-29']
    test = data[data["date"] > '2023-05-29']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.7346153846153847

# %% [raw]
# The accuracy has slightly improved !

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#      actual  predicted       date     team         opponent result
# 188       1          1 2023-08-12  Arsenal  Nott'ham Forest      W
# 189       1          1 2023-08-21  Arsenal   Crystal Palace      W
# 190       0          1 2023-08-26  Arsenal           Fulham      D
# 191       1          1 2023-09-03  Arsenal   Manchester Utd      W
# 192       1          0 2023-09-17  Arsenal          Everton      W
# 193       0          0 2023-09-24  Arsenal        Tottenham      D
# 194       1          1 2023-09-30  Arsenal      Bournemouth      W
# 195       1          0 2023-10-08  Arsenal  Manchester City      W
# 196       0          0 2023-10-21  Arsenal          Chelsea      D
# 197       1          1 2023-10-28  Arsenal    Sheffield Utd      W

# %% [raw]
# A closer look into the dataset will show a slight contradiction as teams such Brighton and Hove Albion are referred as Brighton in the opponent section.

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            1 2023-08-12                  Arsenal
# 1           1            1 2023-08-21                  Arsenal
# 2           0            1 2023-08-26                  Arsenal
# 3           1            1 2023-09-03                  Arsenal
# 4           1            0 2023-09-17                  Arsenal
# ..        ...          ...        ...                      ...
# 675         0            0 2024-04-24  Wolverhampton Wanderers
# 676         1            0 2024-04-27  Wolverhampton Wanderers
# 677         0            0 2024-05-04  Wolverhampton Wanderers
# 678         0            0 2024-05-11  Wolverhampton Wanderers
# 679         0            0 2024-05-19  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0    Nott'ham Forest        W    Arsenal         0            0
# 1     Crystal Palace        W    Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    184
# 0     55
# Name: count, dtype: int64
